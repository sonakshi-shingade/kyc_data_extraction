# %%
def greet(name):
    print(f"My name is {name}")

# %%
greet("Harshit")
# Out:
# My name is Harshit

# %%
data1 = greet("Harshit")
# Out:
# My name is Harshit

# %%
data1  # we can't store it in variable bcz it's not returning anything

# %%
def greet(name):
    return f"My name is {name}"

# %%
greet("Harshit")
# Out:
# 'My name is Harshit'

# %%
data = greet("Harshit")
data
# Out:
# 'My name is Harshit'

# %%
data  # we can store it in variable bcz we r returning
# Out:
# 'My name is Harshit'

# %%
def addition(a,b):
    add = a + b
    return add

# %%
addition(2,3)
# Out:
# 5

# %%
sum_1 = addition(2,3)

# %%
sum_1
# Out:
# 5

# %%
def addition(a,b):
    add = a + b
    print(add)

# %%
addition(5,21)
# Out:
# 26

# %%
sum22 = addition(5,21)
# Out:
# 26

# %%
sum22
